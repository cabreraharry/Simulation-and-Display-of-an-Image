# %% [markdown]
# In these exercises, feel free to leverage the provided code snippets based on your application. Utilize these codes to transform your original image according to the examples given below. Save your file as your Fullname-Exer1.pdf

# %%
# importing libraries to use.
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the image using matplotlib
i = plt.imread('img/harry.jpg')

# %%
# Display the original image
plt.subplot(3, 2, 1)
plt.imshow(i)
plt.title('Original Image')

# Red Component
r = i[:, :, 0]
plt.subplot(3, 2, 2)
plt.imshow(r, cmap='gray')
plt.title('Red Component')

# Green Component
g = i[:, :, 1]
plt.subplot(3, 2, 3)
plt.imshow(g, cmap='gray')
plt.title('Green Component')

# Blue Component
b = i[:, :, 2]
plt.subplot(3, 2, 4)
plt.imshow(b, cmap='gray')
plt.title('Blue Component')

# Color to Gray Image
rg = np.dot(i[..., :3], [0.2989, 0.5870, 0.1140])
plt.subplot(3, 2, 5)
plt.imshow(rg, cmap='gray')
plt.title('Gray Image')

plt.show()

# %% [markdown]
# Complement, Converting and Simulation of an Image

# %%
# Displaying color Image
plt.subplot(2, 2, 1)
plt.imshow(i)
plt.title('Color Image')


# Complement of color Image
c = 1 - i 
plt.subplot(2, 2, 2) # the complement of the color image is calculated by subtracting each pixel value from 1.
plt.imshow(c) #  The result is then displayed, and the title is set to "Complement of Color Image."
plt.title('Complement of Color Image') 


# Gray scale of color Image
r = np.dot(i[..., :3], [0.2989, 0.5870, 0.1140])
plt.subplot(2, 2, 3)
plt.imshow(r, cmap='gray')
plt.title('Gray scale of Color Image')

# Complement of Gray Image
b = 1 - r  # Assuming r is normalized in the range [0, 1]
plt.subplot(2, 2, 4)
plt.imshow(b, cmap='gray')
plt.title('Complement of Gray Image')

# Simulation of an Image (Arithmetic & Logic Operation)
a = np.ones((40, 40))
b = np.zeros((40, 40))
c = np.block([[a, b], [b, a]])
d = np.block([[b, b], [a, a]])
A = 10 * (c + d)
M = c * d
S = c - d
D = c / 4

plt.figure()
plt.subplot(3, 2, 1)
plt.imshow(c)
plt.subplot(3, 2, 2)
plt.imshow(d)
plt.subplot(3, 2, 3)
plt.imshow(A)
plt.subplot(3, 2, 4)
plt.imshow(M)
plt.subplot(3, 2, 5)
plt.imshow(S)
plt.subplot(3, 2, 6)
plt.imshow(D)

plt.show()

# various arithmetic and logic operations are performed on binary images c and d. 
# The results are displayed in a subplot grid, showcasing addition (A), multiplication (M),
# subtraction (S), and division (D) operations.
